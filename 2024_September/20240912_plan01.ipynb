# %% [markdown]
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 800 550">
#   <style>
#     text { font-family: Arial, sans-serif; font-size: 12px; }
#     .week { font-weight: bold; fill: #333; }
#     .topic { fill: #666; }
#     .difficulty { font-style: italic; fill: #999; }
#   </style>
#
#   <!-- 타임라인 -->
#   <line x1="50" y1="50" x2="750" y2="50" stroke="#ccc" stroke-width="2"/>
#
#   <!-- 주차별 마커 -->
#   <circle cx="50" cy="50" r="10" fill="#4CAF50"/>
#   <circle cx="200" cy="50" r="10" fill="#8BC34A"/>
#   <circle cx="350" cy="50" r="10" fill="#FFC107"/>
#   <circle cx="500" cy="50" r="10" fill="#FF5722"/>
#   <circle cx="650" cy="50" r="10" fill="#E91E63"/>
#
#   <!-- 주차 및 주제 -->
#   <g transform="translate(50,80)">
#     <text x="0" y="0" class="week">1주차: 기초 개념</text>
#     <text x="0" y="20" class="topic">• 그래프 개념</text>
#     <text x="0" y="40" class="topic">• 기본 정렬 알고리즘</text>
#     <text x="0" y="60" class="topic">• 재귀 함수</text>
#     <text x="0" y="80" class="topic">• NumPy 기초</text>
#     <text x="0" y="100" class="difficulty">난이도: 낮음</text>
#   </g>
#
#   <g transform="translate(200,80)">
#     <text x="0" y="0" class="week">2주차: 정렬과 기본 통계</text>
#     <text x="0" y="20" class="topic">• 정렬 구현 연습</text>
#     <text x="0" y="40" class="topic">• NumPy를 이용한 데이터 처리</text>
#     <text x="0" y="60" class="topic">• 기본 통계 분석</text>
#     <text x="0" y="80" class="topic">• 통계 분석 실습 (NumPy 활용)</text>
#     <text x="0" y="100" class="difficulty">난이도: 낮음 ~ 중간</text>
#   </g>
#
#   <g transform="translate(350,80)">
#     <text x="0" y="0" class="week">3주차: 그래프 탐색 알고리즘</text>
#     <text x="0" y="20" class="topic">• DFS 알고리즘 이해</text>
#     <text x="0" y="40" class="topic">• DFS 구현 연습 (재귀, 스택)</text>
#     <text x="0" y="60" class="topic">• BFS 알고리즘 이해</text>
#     <text x="0" y="80" class="topic">• BFS 구현 연습</text>
#     <text x="0" y="100" class="difficulty">난이도: 중간</text>
#   </g>
#
#   <g transform="translate(500,80)">
#     <text x="0" y="0" class="week">4주차: 머신러닝 기초</text>
#     <text x="0" y="20" class="topic">• 머신러닝 기본 개념</text>
#     <text x="0" y="40" class="topic">• 간단한 ML 모델 이해</text>
#     <text x="0" y="60" class="topic">• NumPy를 활용한 ML 모델 구현</text>
#     <text x="0" y="80" class="topic">• ML 모델 평가</text>
#     <text x="0" y="100" class="difficulty">난이도: 중간 ~ 높음</text>
#   </g>
#
#   <g transform="translate(650,80)">
#     <text x="0" y="0" class="week">5주차: 심화 학습</text>
#     <text x="0" y="20" class="topic">• 고급 ML 모델 구현</text>
#     <text x="0" y="40" class="topic">• 딥러닝 입문</text>
#     <text x="0" y="60" class="topic">• 그래프 알고리즘 응용</text>
#     <text x="0" y="80" class="topic">• 총 복습 및 모의 구두시험</text>
#     <text x="0" y="100" class="difficulty">난이도: 높음</text>
#   </g>
#
#   <!-- 학습 팁 -->
#   <rect x="50" y="400" width="700" height="130" fill="#f0f0f0" rx="10"/>
#   <text x="60" y="420" font-weight="bold">학습 팁:</text>
#   <text x="60" y="445">• 각 주차의 난이도에 맞춰 학습 시간을 조절하세요.</text>
#   <text x="60" y="470">• 어려운 개념은 이전 주차의 내용과 연결지어 이해해보세요.</text>
#   <text x="60" y="495">• 실습과 구현에 많은 시간을 투자하세요.</text>
#   <text x="60" y="520">• 매일 학습한 내용을 정리하고 말로 설명해보는 연습을 하세요.</text>
# </svg>
